# %% [markdown]
# <a href="https://colab.research.google.com/github/hazin0705/dd/blob/main/9%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

course = {'TOEIC' : 0 , 'TOEFL' : 0 , 'TOEIC SPEAKING' : 0 , 'OPIC' : 0 , 'IELTS' : 0}

print("수강하고 싶은 강좌를 입력하세요")
print("복수개의 강좌를 입력하려면 콤마로 구분하세요")

while True:
  s=input("TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : ")

  if s == '종료':
    break
  for i in s.split(','):
    if i in course:
      course[i] = course[i] + 1
    else:
      print(f"{i}는 등록되지 않은 강좌입니다")

plt.figure(figsize=(5.5,3))
plt.bar(course.keys(),course.values(),color='g',width = 0.6)
plt.title('preferred english course')
plt.xlabel('english course')
plt.ylabel('frequency')
plt.show()
# Out:
# 수강하고 싶은 강좌를 입력하세요
# 복수개의 강좌를 입력하려면 콤마로 구분하세요
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : TOEIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : TOEIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : TOEIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : TOEIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : TOEIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : TOEFL
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : TOEFL
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : TOEFL
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : TOEIC SPEAKING
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : OPIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : OPIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : OPIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : OPIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : OPIC
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : IELTS
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : IELTS
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : IELTS
# TOEIC,TOEFL,TOEIC SPEAKING,OPIC,IELTS,종료 : 종료
