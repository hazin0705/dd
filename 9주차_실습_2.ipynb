# %% [markdown]
# <a href="https://colab.research.google.com/github/hazin0705/dd/blob/main/9%EC%A3%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
year = [2014,2015,2016,2017,2018,2019,2020,2021,2022]
gdp = [3079.9,3250.1,3398.8,3574,3678.2,3721.8,3744,4033.6,4165.5]
plt.figure(figsize=(5,3))
plt.plot(year,gdp, color='#008080', marker = 'h' , linestyle = '--')
plt.title('GDP per capita')
plt.xlabel('Year')
plt.ylabel('ten thousand won')
plt.ylim(2500,4500)
plt.show()
